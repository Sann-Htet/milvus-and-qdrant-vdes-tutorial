# %%
from pymilvus import MilvusClient

client = MilvusClient("milvus_demo.db")

# %%
client.create_collection(
    collection_name="demo_collection",
    dimension=768
)

# %%
import random

docs = [
    "Artificial intelligence was founded as an academic discipline in 1956.",
    "Alan Turing was the first person to conduct substantial research in AI.",
    "Born in Maida Vale, London, Turing was raised in southern England.",
]

vectors = [ [ random.uniform(-1, 1) for _ in range(768) ] for _ in docs ]
data = [ {"id": i, "vector": vectors[i], "text": docs[i], "subject": "history"} for i in range(len(vectors)) ]

print("Data has", len(data), "entities, each with fields: ", data[0].keys())
print("Vector dim:", len(data[0]["vector"]))
# Out:
# Data has 3 entities, each with fields:  dict_keys(['id', 'vector', 'text', 'subject'])
# Vector dim: 768

# %%
res = client.insert(
    collection_name="demo_collection",
    data=data
)

print(res)
# Out:
# {'insert_count': 3, 'ids': [0, 1, 2], 'cost': 0}

# %%
query_vectors = [ [ random.uniform(-1, 1) for _ in range(768) ] ]

res = client.search(
    collection_name="demo_collection", # target collection
    data=query_vectors,                # query vectors
    limit=2,                           # number of returned entities
    output_fields=["text", "subject"], # specifies fields to be returned
)

print(res)
# Out:
# data: ["[{'id': 0, 'distance': 0.03580603003501892, 'entity': {'text': 'Artificial intelligence was founded as an academic discipline in 1956.', 'subject': 'history'}}, {'id': 1, 'distance': 0.004466662183403969, 'entity': {'text': 'Alan Turing was the first person to conduct substantial research in AI.', 'subject': 'history'}}]"] , extra_info: {'cost': 0}

# %%
res = client.query(
    collection_name="demo_collection",
    filter="subject == 'history'",
    output_fields=["text", "subject"],
)

print(res)
# Out:
# data: ["{'id': 0, 'text': 'Artificial intelligence was founded as an academic discipline in 1956.', 'subject': 'history'}", "{'id': 1, 'text': 'Alan Turing was the first person to conduct substantial research in AI.', 'subject': 'history'}", "{'id': 2, 'text': 'Born in Maida Vale, London, Turing was raised in southern England.', 'subject': 'history'}"] , extra_info: {'cost': 0}

# %%
res = client.query(
    collection_name="demo_collection",
    ids=[0,2],
    output_fields=["vector", "text", "subject"]
)

print(res)
# Out:
# data: ["{'id': 0, 'text': 'Artificial intelligence was founded as an academic discipline in 1956.', 'subject': 'history', 'vector': [-0.24426877, 0.10768543, 0.87673944, -0.04368635, -0.19576937, 0.8637175, -0.9618602, 0.98351794, -0.25013003, 0.4476414, 0.36586505, -0.6859718, 0.044982124, 0.60132205, 0.2268318, 0.34227115, 0.86414224, -0.05708103, 0.53135175, 0.17215493, 0.49828407, 0.29960477, -0.14849754, -0.84435517, -0.15442087, -0.86028665, 0.36321142, 0.88901377, -0.34438694, -0.7914911, 0.6826917, -0.368033, 0.990437, -0.02225523, -0.80216444, 0.07627565, -0.43836656, -0.2808349, -0.83656037, 0.8030511, -0.78456527, -0.4959071, 0.3268401, -0.36502728, -0.86553836, -0.6403089, 0.3320205, -0.8928284, 0.23042941, 0.94252616, 0.42401412, -0.114785634, -0.5715655, 0.7705597, 0.8265619, 0.69525135, -0.55921084, -0.7377752, 0.932295, 0.64613146, -0.54382265, -0.57215667, 0.37082726, -0.4790996, 0.23297334, -0.5138749, -0.10365587, 0.1425703, 0.8298683, 0.29132342, -0.52282614, 0.6919151, -0.050651062, -0.25490296, 0.9557331, -0.3714252, -0.6445424, -0.9895441, 0.76252747, 0.52298075, -0.4562717, 0.28022367, -0.7664197, -0.39684162, -0.69466054, 0.78219295, 0.59250814, -0.7358318, 0.17130032, 0.97301126, 0.96955246, 0.41999975, 0.26141977, 0.852381, -0.71330047, -0.23738106, 0.088195704, 0.31553194, 0.36119747, -0.17331654, 0.049834706, -0.36512744, -0.32959214, 0.6245125, 0.4147185, -0.08097291, 0.3548139, -0.9846406, -0.78320223, -0.08288644, 0.3124451, 0.73830277, 0.6359903, -0.3012022, 0.14949876, -0.3539946, -0.48036513, 0.10830754, -0.31604365, -0.3919574, 0.11176098, 0.06516192, -0.23965654, -0.5932138, 0.9755925, 0.043022774, -0.32275036, -0.54021823, -0.45723563, -0.10539682, 0.03358149, -0.30282614, -0.86544985, -0.21091574, 0.7019575, 0.40412217, 0.21172072, -0.14852262, -0.74394494, 0.94453675, 0.88787514, 0.29517904, -0.86707276, -0.42536855, -0.5421969, -0.108331956, 0.19659463, 0.7888622, 0.25656235, -0.7159161, -0.62420505, -0.6812271, -0.3550669, 0.41561928, 0.8983775, 0.734384, 0.35387492, -0.58545905, 0.5574001, 0.009731735, -0.4421487, 0.3560555, -0.7601226, -0.005428672, -0.02700253, 0.9880786, 0.460617, 0.26654702, -0.2209949, -0.38935873, 0.37868848, 0.32192057, 0.46344313, 0.95193434, 0.70333207, 0.796774, -0.10173532, -0.31651512, -0.78992796, 0.44511658, 0.21413329, -0.12358199, -0.021002503, -0.8704067, -0.3165701, 0.002346987, 0.8769331, 0.78140175, 0.96267974, -0.6782115, -0.13739608, -0.049274903, 0.21149583, -0.95329696, -0.80554146, -0.4741142, 0.41082406, 0.12901956, 0.63133365, 0.035411432, 0.6809729, 0.26061055, -0.29034472, 0.7058176, -0.3347973, 0.9190907, -0.33955485, 0.596259, 0.6264007, -0.5931766, -0.34307566, 0.87772024, -0.30393642, -0.17704129, -0.5660654, 0.84571344, 0.107912794, 0.7539196, -0.15469433, -0.36595947, -0.683998, -0.9892526, 0.3408959, -0.453159, -0.065838955, -0.09585338, 0.5141817, -0.66365594, -0.6003889, -0.8522565, -0.0006424567, 0.29560378, -0.046523724, 0.62957275, 0.94962555, 0.037465937, 0.83248365, 0.9553592, -0.35491678, -0.013636056, 0.17627369, 0.41834754, 0.4393559, 0.31859362, -0.28906184, -0.94772136, -0.11129245, -0.76894236, -0.41703466, -0.73757654, 0.23941159, 0.032088507, 0.9326888, -0.33653387, -0.6913636, 0.59480345, 0.3794245, -0.23550612, 0.30964443, 0.6238856, 0.20523086, -0.15969548, -0.7942169, -0.104527414, 0.10473737, -0.16520542, -0.064099945, 0.25208026, 0.23819587, -0.75627756, -0.85060436, 0.6360314, -0.27758828, 0.45448175, 0.38873783, -0.6487247, -0.5183452, -0.17050123, -0.506572, -0.50237316, 0.88523114, -0.5052402, -0.5701275, 0.66693884, -0.24722111, 0.42141837, 0.2316453, -0.9286762, -0.24785328, -0.6400139, 0.038804755, 0.631843, 0.9040387, 0.7818113, 0.49605784, 0.09857436, 0.6839724, -0.1893775, -0.6566404, -0.66747606, 0.0515874, 0.18750715, -0.34429932, 0.39022908, -0.32126668, -0.85685045, 0.9993746, 0.9049207, 0.0043693436, -0.6654577, 0.16653556, 0.99641675, 0.1295185, 0.6012828, 0.56312335, 0.44469565, -0.22018272, 0.1 ...

# %%
# Delete entities by primary key
res = client.delete(
    collection_name="demo_collection",
    ids=[0,2]
)

print(res)

# Delete entities by a filter expression
res = client.delete(
    collection_name="demo_collection",
    filter="subject == 'biology'",
)

print(res)
# Out:
# [0, 2]
# {'delete_count': 0, 'cost': 0}

# %%
from pymilvus import MilvusClient

client = MilvusClient("milvus_demo.db")

# %%
# 15. Drop collection
client.drop_collection(
    collection_name="demo_collection"
)

# %% [markdown]
# ---
